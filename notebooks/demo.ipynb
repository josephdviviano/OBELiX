# %% [markdown]
# # OBELiX External Datasets Demo
#
# This notebook demonstrates how to load, explore, and combine the external solid-state electrolyte (SSE) datasets available in the OBELiX package.
#
# For the full OBELiX dataset and paper, see: https://arxiv.org/html/2502.14234v2

# %% [markdown]
# ## Setup

# %%
import obelix
from obelix import LiIon, Laskowski, ShonAndMin, McHaffie, Dataset

print(f"OBELiX version: {obelix.__version__}")
# Out:
# OBELiX version: 1.1.1

# %% [markdown]
# ## LiIon Dataset

# %%
liion = LiIon()
print(f"LiIon: {len(liion)} entries")
print(f"Columns: {liion.dataframe.columns.tolist()}")
# Out:
# LiIon: 450 entries
# Columns: ['Reduced Composition', 'DOI', 'temperature', 'Ionic conductivity (S cm-1)', 'log_target', 'Family', 'ChemicalFamily']

# %%
liion.dataframe.head(10)
# Out:
#                 Reduced Composition                             DOI  \
# ID
# LIION_0002                  Li2OHBr          10.1002/aenm.201700971
# LIION_0003             Li2.4OH0.6Cl          10.1002/aenm.201700971
# LIION_0004             Li2.1OH0.9Cl          10.1002/aenm.201700971
# LIION_0005                  Li2OHCl          10.1002/aenm.201700971
# LIION_0006             Li2.7OH0.3Cl          10.1002/aenm.201700971
# LIION_0008                 Li6PO5Cl          10.1002/zaac.201000121
# LIION_0017             Li7La3Zr2O12          10.1002/anie.200701144
# LIION_0018         Li3.4Si0.4P0.6S4          10.1006/jssc.2002.9701
# LIION_0020  Li7.06La3Zr1.94Y0.06O12    10.1016/j.elecom.2011.08.014
# LIION_0021   Li6.4Al0.19La3Zr2O11.8  10.1016/j.jpowsour.2012.02.100
#
#             temperature  Ionic conductivity (S cm-1)  log_target  \
# ID
# LIION_0002        22.06                 5.400000e-07   -6.267606
# LIION_0003        26.00                 8.900000e-08   -7.050610
# LIION_0004        26.00                 8.050000e-08   -7.094204
# LIION_0005        26.00                 7.110000e-08   -7.148130
# LIION_0006        26.00                 7.300000e-09   -8.136677
# LIION_0008        25.00                 1.000000e-09   -9.000000
# LIION_0017        24.85                 5.110000e-04   -3.291579
# LIION_0018        27.00                 6.400000e-04   -3.193820
# LIION_0020        25.00                 9.560000e-04   -3.019542
# LIION_0021        24.85                 3.100000e-04   -3.508638
#
#                      Family           ChemicalFamily
# ID
# LIION_0002  Anti-Perovskite  Oxides and Other Anions
# LIION_0003  Anti-Perovskite  Oxides and Other Anions
# LIION_0004  Anti-Perovskite  Oxides and Other Anions
# LIION_0005  Anti-Perovskite  Oxides and Other Anions
# LIION_0006  Anti-Perovskite  Oxides and Other Anions
# LIION_0008       Argyrodite  Oxides and Other Anions
# LIION_0017           Garnet                   Oxides
# LIION_0018     Thio-LISICON                Sulphides
# LIION_0020           Garnet                   Oxides
# LIION_0021           Garnet                   Oxides

# %%
liion.dataframe['Ionic conductivity (S cm-1)'].describe()
# Out:
# count    4.500000e+02
# mean     5.744332e-04
# std      1.934811e-03
# min      5.000000e-16
# 25%      7.285000e-07
# 50%      3.950000e-05
# 75%      4.002500e-04
# max      2.500000e-02
# Name: Ionic conductivity (S cm-1), dtype: float64

# %% [markdown]
# ## Laskowski Dataset

# %%
laskowski = Laskowski(local=True)
print(f"Laskowski: {len(laskowski)} entries")
print(f"Columns: {laskowski.dataframe.columns.tolist()}")
# Out:
# Laskowski: 1346 entries
# Columns: ['Reduced Composition', 'Ionic conductivity (S cm-1)', 'Ea (eV)', 'Space group', 'ICSD Entry', 'DOI']

# %%
laskowski.dataframe.head(10)
# Out:
#           Reduced Composition Ionic conductivity (S cm-1)  Ea (eV)  \
# ID
# LASK_0000           LiAlSi3O8                    1.30E-10      NaN
# LASK_0001         LiSn2(PO4)3                    2.04E-09      NaN
# LASK_0002             Li7BiO6                    8.80E-07    0.580
# LASK_0003             Li7SbO6                    6.70E-08    0.700
# LASK_0004            Li7P3S11                    1.70E-02    0.170
# LASK_0005            Li7P3S11                    3.20E-03    0.124
# LASK_0006           LiV(PO4)F                    8.10E-07    0.230
# LASK_0007            Li2B3PO8                    5.80E-15    0.760
# LASK_0008            Li3BP2O8                    9.60E-12    0.620
# LASK_0009          Li2NaBP2O8                    4.40E-18    1.210
#
#            Space group  ICSD Entry                         DOI
# ID
# LASK_0000          2.0     81980.0          10.1039/c4cp03609c
# LASK_0001          2.0     83832.0      10.1002/chin.199345017
# LASK_0002          2.0    155950.0           10.1021/ic030208w
# LASK_0003          2.0    413370.0           10.1021/ic030208w
# LASK_0004          2.0    157654.0      10.1002/adma.200401286
# LASK_0005          2.0    157654.0   10.1016/j.ssi.2007.05.020
# LASK_0006          2.0    183876.0   10.1016/j.ssi.2013.04.002
# LASK_0007          2.0    248343.0  10.1016/j.jssc.2014.11.024
# LASK_0008          2.0    248343.0  10.1016/j.jssc.2014.11.024
# LASK_0009          2.0    291512.0  10.1016/j.jssc.2014.11.024

# %%
laskowski.dataframe['Ionic conductivity (S cm-1)'].describe()
# Out:
# count       1346
# unique       955
# top       <1E-10
# freq          50
# Name: Ionic conductivity (S cm-1), dtype: object

# %% [markdown]
# ## ShonAndMin Dataset
#
# The Shon & Min dataset is extracted from the supplementary information of their ACS Omega (2023) paper. The raw data undergoes several cleaning steps:
#
# 1. **Ionic conductivity parsing** &mdash; human-written values (ranges, varied units) are normalized to S/cm
# 2. **Formula validation** &mdash; compositions are validated with pymatgen
# 3. **Minimum conductivity** &mdash; for each (composition, DOI) pair, only the minimum conductivity is kept
# 4. **Room temperature filter** &mdash; only 25 &plusmn; 7 &deg;C measurements are retained

# %%
shonandmin = ShonAndMin(local=True)
print(f"ShonAndMin: {len(shonandmin)} entries")
print(f"Columns: {shonandmin.dataframe.columns.tolist()}")
# Out:
# ShonAndMin: 2261 entries
# Columns: ['Reduced Composition', 'Raw_unit', 'Ionic conductivity (S cm-1)', 'DOI', 'Date', 'StructureType']

# %%
shonandmin.dataframe.head(10)
# Out:
#         Reduced Composition Raw_unit  Ionic conductivity (S cm-1)  \
# ID
# SM_2239            (FSO2)2N    Scm−1                 1.000000e-03
# SM_1984    (La0.8Sr0.2)MnO3    Scm−1                 1.000000e-07
# SM_2001           Al2(WO3)4    Scm−1                 4.000000e-06
# SM_3470           Al2(WO4)3    Scm−1                 3.400000e-06
# SM_0328           Al2(WO4)3    Scm−1                 1.060000e-05
# SM_3878               Al2O3     S/cm                 2.000000e-03
# SM_1986               Al2O3     S/cm                 1.000000e-07
# SM_0493               Al2O3    Scm−1                 1.000000e-03
# SM_1271               Al2O3    Scm−1                 2.490000e-05
# SM_2364               Al2O3    Scm−1                 2.100000e-02
#
#                                    DOI        Date StructureType
# ID
# SM_2239             10.1039/C4TA05833J  2015/01/20           NaN
# SM_1984             10.1039/C2CP42919E  2013/01/23           NaN
# SM_2001             10.1039/C3RA42211A  2013/07/01           NaN
# SM_3470  10.1016/S0167-2738(00)00443-4  2000-11-30           NaN
# SM_0328  10.1016/S0167-2738(00)00552-X  2000-11-30           NaN
# SM_3878  10.1016/S0013-4686(99)00215-7  1999-10-19           NaN
# SM_1986  10.1016/S0167-2738(03)00025-0  2003-02-26           NaN
# SM_0493  10.1016/S0378-7753(99)00529-7  2000-05-24           NaN
# SM_1271      10.1016/j.cap.2016.05.021  2016-05-27           NaN
# SM_2364   10.1016/j.carbon.2012.09.013  2012-09-16           NaN

# %%
shonandmin.dataframe['Ionic conductivity (S cm-1)'].describe()
# Out:
# count    2.261000e+03
# mean     2.164952e-02
# std      1.039994e-01
# min      1.000000e-18
# 25%      1.000000e-07
# 50%      5.090000e-05
# 75%      1.000000e-03
# max      1.000000e+00
# Name: Ionic conductivity (S cm-1), dtype: float64

# %% [markdown]
# ## McHaffie Dataset
#
# The McHaffie dataset (McHaffie et al., 2025) contains 571 lithium-ion conductivity entries, each with an ICSD collection code and DOI. Because ICSD structural data requires a licence, the `get_space_groups()`, `get_lattice_parameters()`, and `get_cifs()` methods raise `NotImplementedError` as stubs for future integration.

# %%
mchaffie = McHaffie(local=True)
print(f"McHaffie: {len(mchaffie)} entries")
print(f"Columns: {mchaffie.dataframe.columns.tolist()}")
# Out:
# McHaffie: 571 entries
# Columns: ['Reduced Composition', 'ICSD Collection Code', 'DOI', 'Ionic conductivity (S cm-1)', 'Extrapolation Temperature (K)']

# %%
mchaffie.dataframe.head(10)
# Out:
#                       Reduced Composition  ICSD Collection Code  \
# ID
# MCH_0000            Li6.7La3Zr1.7Ta0.3O12                   885
# MCH_0001            Li6.5La3Zr1.5Ta0.5O12                   894
# MCH_0002                       Li4B7O12Cl                  1125
# MCH_0003                          Li2TeO4                  1485
# MCH_0004                           Li2SO4                  2512
# MCH_0005                       Li6CuB4O10                  4819
# MCH_0006     Li10.2(Sn0.2Si0.8)1.2P1.8S12                  5667
# MCH_0007  Li10.35(Sn0.2Si0.8)1.35P1.65S12                  5669
# MCH_0008            Li1.8LaNbTa1.2Ti0.8O7                  5926
# MCH_0009                      LiTi2(PO4)3                  7930
#
#                                                DOI  \
# ID
# MCH_0000                     10.2109/jcersj2.16019
# MCH_0001                     10.2109/jcersj2.16019
# MCH_0002                 10.1107/S0567740877009443
# MCH_0003              10.1016/0025-5408(94)90011-6
# MCH_0004                  10.1051/epjap/2014130433
# MCH_0005             10.1021/acs.inorgchem.8b01785
# MCH_0006             10.1021/acs.chemmater.9b00743
# MCH_0007             10.1021/acs.chemmater.9b00743
# MCH_0008                        10.1039/C9DT03547H
# MCH_0009  10.1016/j.solidstatesciences.2016.08.011
#
#           Ionic conductivity (S cm-1) Extrapolation Temperature (K)
# ID
# MCH_0000                 5.040000e-04                            na
# MCH_0001                 8.420000e-04                            na
# MCH_0002                 2.400000e-05                            na
# MCH_0003                 3.790000e-16                           580
# MCH_0004                 1.400000e-14                        473.15
# MCH_0005                 1.000000e-13                           420
# MCH_0006                 2.500000e-03                            na
# MCH_0007                 1.100000e-02                            na
# MCH_0008                 4.260000e-09                            na
# MCH_0009                 3.130000e-06                            na

# %%
mchaffie.dataframe['Ionic conductivity (S cm-1)'].describe()
# Out:
# count    5.710000e+02
# mean     9.604319e-04
# std      2.686023e-03
# min      2.700000e-31
# 25%      1.330000e-08
# 50%      1.110000e-05
# 75%      7.005000e-04
# max      2.800000e-02
# Name: Ionic conductivity (S cm-1), dtype: float64

# %% [markdown]
# ## Combining Datasets with `+`
#
# The `+` operator concatenates two `Dataset` objects and automatically deduplicates by canonical reduced composition (via pymatgen). All unique columns from both datasets are retained &mdash; missing values are filled with NaN where one dataset lacks a column present in the other.

# %%
combined = liion + laskowski

naive_total = len(liion) + len(laskowski)
print(f"LiIon:                {len(liion)} entries")
print(f"Laskowski:            {len(laskowski)} entries")
print(f"Naive sum:            {naive_total} entries")
print(f"Combined (deduped):   {len(combined)} entries")
print(f"Duplicates removed:   {naive_total - len(combined)}")
print(f"\nColumns: {combined.dataframe.columns.tolist()}")
# Out:
# LiIon:                450 entries
# Laskowski:            1346 entries
# Naive sum:            1796 entries
# Combined (deduped):   1377 entries
# Duplicates removed:   419
#
# Columns: ['Reduced Composition', 'DOI', 'temperature', 'Ionic conductivity (S cm-1)', 'log_target', 'Family', 'ChemicalFamily', 'Ea (eV)', 'Space group', 'ICSD Entry']

# %%
combined.dataframe.head()
# Out:
#            Reduced Composition                     DOI  temperature  \
# ID
# LIION_0002             Li2OHBr  10.1002/aenm.201700971        22.06
# LIION_0003        Li2.4OH0.6Cl  10.1002/aenm.201700971        26.00
# LIION_0004        Li2.1OH0.9Cl  10.1002/aenm.201700971        26.00
# LIION_0005             Li2OHCl  10.1002/aenm.201700971        26.00
# LIION_0006        Li2.7OH0.3Cl  10.1002/aenm.201700971        26.00
#
#            Ionic conductivity (S cm-1)  log_target           Family  \
# ID
# LIION_0002                    0.000001   -6.267606  Anti-Perovskite
# LIION_0003                         0.0   -7.050610  Anti-Perovskite
# LIION_0004                         0.0   -7.094204  Anti-Perovskite
# LIION_0005                         0.0   -7.148130  Anti-Perovskite
# LIION_0006                         0.0   -8.136677  Anti-Perovskite
#
#                      ChemicalFamily  Ea (eV)  Space group  ICSD Entry
# ID
# LIION_0002  Oxides and Other Anions      NaN          NaN         NaN
# LIION_0003  Oxides and Other Anions      NaN          NaN         NaN
# LIION_0004  Oxides and Other Anions      NaN          NaN         NaN
# LIION_0005  Oxides and Other Anions      NaN          NaN         NaN
# LIION_0006  Oxides and Other Anions      NaN          NaN         NaN

# %% [markdown]
# You can chain additions to combine all four datasets at once. Deduplication is applied at each step:

# %%
all_external = liion + laskowski + shonandmin + mchaffie

print(f"All external datasets: {len(all_external)} entries")
print(f"Columns: {all_external.dataframe.columns.tolist()}")
# Out:
# All external datasets: 1804 entries
# Columns: ['Reduced Composition', 'DOI', 'temperature', 'Ionic conductivity (S cm-1)', 'log_target', 'Family', 'ChemicalFamily', 'Ea (eV)', 'Space group', 'ICSD Entry', 'Raw_unit', 'Date', 'StructureType', 'ICSD Collection Code', 'Extrapolation Temperature (K)']

# %%
merged = Dataset.merge_datasets(liion, laskowski, shonandmin, mchaffie)
merged_with_dups = Dataset.merge_datasets(liion, laskowski, shonandmin, mchaffie, remove_duplicates=False)

print(f"Merged (deduplicated):    {len(merged)} entries")
print(f"Merged (with duplicates): {len(merged_with_dups)} entries")
print(f"Duplicates removed:       {len(merged_with_dups) - len(merged)}")
print(f"\nColumns: {merged.dataframe.columns.tolist()}")
# Out:
# Merged (deduplicated):    1804 entries
# Merged (with duplicates): 4628 entries
# Duplicates removed:       2824
#
# Columns: ['Reduced Composition', 'Ionic conductivity (S cm-1)', 'DOI']

# %%
merged.dataframe.head(10)
# Out:
#                 Reduced Composition Ionic conductivity (S cm-1)  \
# ID
# LIION_0002                  Li2OHBr                    0.000001
# LIION_0003             Li2.4OH0.6Cl                         0.0
# LIION_0004             Li2.1OH0.9Cl                         0.0
# LIION_0005                  Li2OHCl                         0.0
# LIION_0006             Li2.7OH0.3Cl                         0.0
# LIION_0008                 Li6PO5Cl                         0.0
# LIION_0017             Li7La3Zr2O12                    0.000511
# LIION_0018         Li3.4Si0.4P0.6S4                     0.00064
# LIION_0020  Li7.06La3Zr1.94Y0.06O12                    0.000956
# LIION_0021   Li6.4Al0.19La3Zr2O11.8                     0.00031
#
#                                        DOI
# ID
# LIION_0002          10.1002/aenm.201700971
# LIION_0003          10.1002/aenm.201700971
# LIION_0004          10.1002/aenm.201700971
# LIION_0005          10.1002/aenm.201700971
# LIION_0006          10.1002/aenm.201700971
# LIION_0008          10.1002/zaac.201000121
# LIION_0017          10.1002/anie.200701144
# LIION_0018          10.1006/jssc.2002.9701
# LIION_0020    10.1016/j.elecom.2011.08.014
# LIION_0021  10.1016/j.jpowsour.2012.02.100

# %% [markdown]
# ## Cross-Dataset Deduplication with `remove_matching_entries`
#
# When combining data from different sources, entries often overlap. The `remove_matching_entries` method identifies and removes duplicates based on:
#
# 1. **Composition match** &mdash; canonical reduced formula equivalence (e.g., `Li2O` and `Li4O2` are treated as the same)
# 2. **DOI match** &mdash; same DOI confirms the measurement comes from the same paper
# 3. **Missing DOI** &mdash; if the entry has no DOI but the composition exists in the other dataset with a known DOI, it is also removed
#
# Entries with the same composition but *different* DOIs are kept &mdash; they represent distinct measurements from different papers.

# %%
liion_cleaned = liion.remove_matching_entries(laskowski)

print(f"LiIon before:           {len(liion)} entries")
print(f"LiIon after dedup:      {len(liion_cleaned)} entries")
print(f"Entries removed:        {len(liion) - len(liion_cleaned)}")
# Out:
# LiIon before:           450 entries
# LiIon after dedup:      382 entries
# Entries removed:        68

# %%
shon_cleaned = shonandmin.remove_matching_entries(laskowski)

print(f"ShonAndMin before:      {len(shonandmin)} entries")
print(f"ShonAndMin after dedup: {len(shon_cleaned)} entries")
print(f"Entries removed:        {len(shonandmin) - len(shon_cleaned)}")
# Out:
# ShonAndMin before:      2261 entries
# ShonAndMin after dedup: 2253 entries
# Entries removed:        8

# %% [markdown]
# Note that the original datasets are never modified &mdash; `remove_matching_entries` always returns a new `Dataset`:

# %%
print(f"Original LiIon still has {len(liion)} entries (unchanged)")
# Out:
# Original LiIon still has 450 entries (unchanged)

# %% [markdown]
# ## Diagnosing Merges with `diagnose_merge`
#
# Before committing to a merge, you can inspect exactly which entries overlap between two datasets using `diagnose_merge`. It returns a DataFrame showing all rows from both sides that share a canonical reduced composition, along with:
#
# - `_source` &mdash; which dataset the row came from (`"self"` or `"other"`)
# - `_canonical` &mdash; the canonical reduced formula used for matching
# - `_kept` &mdash; whether this row would survive deduplication (first occurrence wins)

# %%
report = liion.diagnose_merge(laskowski)

print(f"Overlapping entries between LiIon and Laskowski: {len(report)}")
print(f"  Entries kept (from LiIon):     {report['_kept'].sum()}")
print(f"  Entries dropped (duplicates):  {(~report['_kept']).sum()}")
print(f"  Unique compositions matched:   {report['_canonical'].nunique()}")

report.head(10)
# Out:
# Overlapping entries between LiIon and Laskowski: 492
#   Entries kept (from LiIon):     163
#   Entries dropped (duplicates):  329
#   Unique compositions matched:   163
#         Reduced Composition                                 DOI  temperature  \
# 0    Li6Sr0.5Ba0.5La2Ta2O12                   10.1149/1.2800764         20.0
# 1    Li6Ba0.5Sr0.5La2Ta2O12                   10.1021/am4060194          NaN
# 2  Li6.25Ba1.25La1.75Ta2O12           10.1007/s11581-007-0097-8         18.0
# 3  Li6.25Ba1.25La1.75Ta2O12                                 NaN          NaN
# 4           Li6BaLa2Nb2O12     10.1111/j.1551-2916.2005.00060.x         22.0
# 5            Li6BaLa2Nb2O12                                 NaN          NaN
# 6            Li6BaLa2Ta2O12                                 NaN          NaN
# 7            Li6BaLa2Ta2O12                                 NaN          NaN
# 8            Li6BaLa2Ta2O12                   10.1021/am4060194          NaN
# 9            Li6BaLa2Ta2O12  10.1016/j.materresbull.2012.04.032          NaN
#
#   Ionic conductivity (S cm-1)  log_target  Family ChemicalFamily _source  \
# 0                    0.000008   -5.092589  Garnet         Oxides    self
# 1                    7.10E-06         NaN     NaN            NaN   other
# 2                    0.000027   -4.568636  Garnet         Oxides    self
# 3                    5.05E-05         NaN     NaN            NaN   other
# 4                    0.000006   -5.221849  Garnet         Oxides    self
# 5                    6.00E-06         NaN     NaN            NaN   other
# 6                    4.00E-05         NaN     NaN            NaN   other
# 7                    4.00E-05         NaN     NaN            NaN   other
# 8                    1.50E-05         NaN     NaN            NaN   other
# 9                    2.45E-05         NaN     NaN            NaN   other
#
#                  _canonical  Ea (eV)  Space group  ICSD Entry  _kept
# 0    Ba0.5Sr0.5Li6La2Ta2O12      NaN          NaN         NaN   True
# 1    Ba0.5Sr0.5Li6La2Ta2O12    0.450        230.0    237199.0  False
# 2  Ba1.25Li6.25La1.75Ta2O12      NaN          NaN         NaN   True
# 3  Ba1.25Li6.25La1.75Ta2O12    0.395        230.0         NaN  False
# 4            BaLi6La2Nb2O12      NaN          NaN         NaN   True
# 5            BaLi6La2Nb2O12    0.440        199.0         NaN  False
# 6            BaLi6La2Ta2O12    0.400        230.0    237201.0   True
# 7            BaLi6La2Ta2O12    0.400        230.0         NaN  False
# 8            BaLi6La2Ta2O12    0.470        230.0    237201.0  False
# 9            BaLi6La2Ta2O12    0.400        230.0    185602.0  False

# %% [markdown]
# ## Summary
#
# | Class | Entries | Key Columns | Source |
# |-------|---------|-------------|--------|
# | `LiIon` | See above | Reduced Composition, Ionic conductivity, DOI, Family | Liverpool Materials Discovery Server |
# | `Laskowski` | See above | Reduced Composition, Ionic conductivity, DOI, Space group, ICSD | Laskowski et al. (2023) |
# | `ShonAndMin` | See above | Reduced Composition, Ionic conductivity, DOI | Shon & Min, ACS Omega (2023) |
# | `McHaffie` | See above | Reduced Composition, Ionic conductivity, DOI, ICSD Collection Code | McHaffie et al. (2025) |
#
# **Key operations:**
#
# | Operation | Method | Deduplicates? | Notes |
# |-----------|--------|---------------|-------|
# | Combine | `ds1 + ds2` | By composition | Keeps all unique columns, deduplicates by canonical reduced formula |
# | Merge | `Dataset.merge_datasets(ds1, ds2, ...)` | By composition (default) | Restricts to curated column set |
# | Remove overlaps | `ds1.remove_matching_entries(ds2)` | By composition + DOI | Keeps entries with different DOIs |
# | Diagnose | `ds1.diagnose_merge(ds2)` | N/A | Inspect overlapping entries before merging |
